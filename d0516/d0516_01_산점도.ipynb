# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

matplotlib.rcParams['axes.unicode_minus'] = False 
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # : windows 사용자용
matplotlib.rcParams['font.size'] = '15'

# %%
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기  학년
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python   3
# 2번    강태원  구로고  184   40   35   50  55  25        Java   3
# 3번    강호림  구로고  168   80   75   70  80  75  javascript   2
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN   1
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN   1
# 6번    박동현  단지고  202   80  100   95  85  80           C   3
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON   2
# 8번    승근열  단지고  190  100   85   90  95  95          c#   2

# %%
plt.bar(df['이름'],df['국어'])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.plot(df['이름'],df['영어'])
plt.plot(df['이름'],df['수학'])

# %% [markdown]
# ### 산점도 그래프  :  scatter()

# %%
plt.scatter(df['영어'],df['수학'])
plt.xlabel('영어점수',loc='right')
plt.ylabel('수학점수',loc='top')
# Out:
# Text(0, 1, '수학점수')

# %%
plt.scatter(df['영어'],df['수학'])
plt.scatter(df['영어'],df['과학'])

# %%
## 학년별로 크기 분류
df['학년']
# Out:
# 지원번호
# 1번    3
# 2번    3
# 3번    2
# 4번    1
# 5번    1
# 6번    3
# 7번    2
# 8번    2
# Name: 학년, dtype: int64

# %%
plt.scatter(df['영어'],df['수학'])
plt.xlabel('영어점수',loc='right')
plt.ylabel('수학점수',loc='top')
# Out:
# Text(0, 1, '수학점수')

# %%
np.random.rand(8)*1000
# Out:
# array([ 11.5161681 , 324.31792477, 804.99920396, 647.52235665,
#         21.87703655, 901.23970013, 246.603238  , 354.20726228])

# %%
sizes = np.random.rand(8)*1000

# %%
# s : 크기 조절

# plt.scatter(df['영어'],df['수학'],s = sizes)  # size가 랜덤으로 그려짐
plt.scatter(df['영어'],df['수학'],s = 1000)     # 사이즈가 1000으로 일괄적용

# %%
# 학년별 크기조절 1*500 = 500 , 2*500 = 1000, 3*500 = 1500
# 학년별로 scatter를 각각 적용해도 됨

sizes = df['학년']*500
plt.scatter(df['영어'],df['수학'],s = sizes) 

plt.xlabel('영어점수')
plt.ylabel('수학점수')
# Out:
# Text(0, 0.5, '수학점수')

# %%
# 학년별 컬러 적용 추가

sizes = df['학년']*500
plt.scatter(df['영어'],df['수학'],s = sizes, c =df['학년'],cmap='viridis') 

plt.xlabel('영어점수')
plt.ylabel('수학점수')

# 컬러바 눈금표시  -  ticks : 범위지정 /  라벨표시 : label   /  컬러바크기조절 : shrink   /  하단배치 : orientation='horizontal'
plt.colorbar(ticks=[1,2,3], label='학년', shrink=0.3, orientation='horizontal')

# %%
# stu_score1 에서 50명만 합계점수로 산점도 그래프 출력
# x축 이름은 90도로 돌리기

df = pd.read_csv('../z20_data/stu_score1.csv')
df.head(20)
# Out:
#     no         id  kor  eng  math  total        avg  rank      c_date
# 0    1    Joelynn   55   87    68    210  70.000000     0  2024-04-04
# 1    2     Bambie   73   69    77    219  73.000000     0  2024-04-01
# 2    3       Orin   92   97    90    279  93.000000     0  2024-04-04
# 3    4       Puff   98   60    78    236  78.666667     0  2024-04-04
# 4    5    Godfree   66   72    59    197  65.666667     0  2024-04-06
# 5    6      Penny   64   66    63    193  64.333333     0  2024-04-08
# 6    7      Matti   84   81    97    262  87.333333     0  2024-04-02
# 7    8   Catherin   58   69    95    222  74.000000     0  2024-04-02
# 8    9      Flora   95   58    72    225  75.000000     0  2024-04-03
# 9   10     Rhodia   60   97    72    229  76.333333     0  2024-04-09
# 10  11    Atlante   63   99    87    249  83.000000     0  2024-04-09
# 11  12  Zacharias   80   59    72    211  70.333333     0  2024-04-01
# ...

# %%
plt.figure(dpi=200)
plt.scatter(df['id'].head(20),df['total'].head(20))
plt.xticks(rotation=90)
plt.xlabel('id', loc='right',color='purple')
plt.ylabel('total',loc='top', color ='green')
# Out:
# Text(0, 1, 'total')
