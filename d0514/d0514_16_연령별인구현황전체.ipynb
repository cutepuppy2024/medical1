# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd


# 한글설정
matplotlib.rcParams['axes.unicode_minus'] = False 
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # : windows 사용자용
matplotlib.rcParams['font.size'] = '15'

# %%
import pandas as pd
df = pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,index_col='행정기관',usecols=('B,E:Y'))
df
# Out:
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         726,460  1,072,653  1,211,077  1,211,949  1,524,378  1,823,908
# 서울특별시      116,614    161,429    185,689    197,425    271,237    390,716
# 부산광역시       41,333     63,912     68,919     67,836     93,245    109,745
# 대구광역시       31,269     49,000     55,029     57,661     74,228     81,001
# 인천광역시       43,664     63,028     70,593     69,580     86,548    108,831
# 광주광역시       21,506     32,852     38,227     39,769     49,779     53,357
# 대전광역시       21,241     31,032     35,302     37,083     48,557     57,944
# 울산광역시       16,646     26,693     29,418     28,366     33,283     39,507
# 세종특별자치시      9,524     13,733     14,079     10,808      9,307     10,329
# 경기도        216,863    313,113    345,546    335,021    411,620    501,356
# 강원도         20,663     28,244     33,186     35,219     46,654     48,339
# 충청북도        22,631     32,948     37,693     37,809     47,397     57,064
# ...

# %%
for i in range(len(df)):
    df.iloc[i] = df.iloc[i].str.replace(',','').astype(int)
df
# Out:
#              0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         726460  1072653  1211077  1211949  1524378  1823908  1737714
# 서울특별시      116614   161429   185689   197425   271237   390716   379852
# 부산광역시       41333    63912    68919    67836    93245   109745   103536
# 대구광역시       31269    49000    55029    57661    74228    81001    76198
# 인천광역시       43664    63028    70593    69580    86548   108831   107658
# 광주광역시       21506    32852    38227    39769    49779    53357    45743
# 대전광역시       21241    31032    35302    37083    48557    57944    51617
# 울산광역시       16646    26693    29418    28366    33283    39507    37536
# 세종특별자치시      9524    13733    14079    10808     9307    10329    13538
# 경기도        216863   313113   345546   335021   411620   501356   491074
# 강원도         20663    28244    33186    35219    46654    48339    43021
# 충청북도        22631    32948    37693    37809    47397    57064    51561
# ...

# %%
df['0~14세'] = 0
df['15~64세'] = 0
df['65세 이상'] = 0
df
# Out:
#              0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         726460  1072653  1211077  1211949  1524378  1823908  1737714
# 서울특별시      116614   161429   185689   197425   271237   390716   379852
# 부산광역시       41333    63912    68919    67836    93245   109745   103536
# 대구광역시       31269    49000    55029    57661    74228    81001    76198
# 인천광역시       43664    63028    70593    69580    86548   108831   107658
# 광주광역시       21506    32852    38227    39769    49779    53357    45743
# 대전광역시       21241    31032    35302    37083    48557    57944    51617
# 울산광역시       16646    26693    29418    28366    33283    39507    37536
# 세종특별자치시      9524    13733    14079    10808     9307    10329    13538
# 경기도        216863   313113   345546   335021   411620   501356   491074
# 강원도         20663    28244    33186    35219    46654    48339    43021
# 충청북도        22631    32948    37693    37809    47397    57064    51561
# ...

# %%
for i in range(len(df)):
    df.iloc[i,-3] = df.iloc[i,0]+df.iloc[i,1]+df.iloc[i,2]
df
# Out:
#              0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         726460  1072653  1211077  1211949  1524378  1823908  1737714
# 서울특별시      116614   161429   185689   197425   271237   390716   379852
# 부산광역시       41333    63912    68919    67836    93245   109745   103536
# 대구광역시       31269    49000    55029    57661    74228    81001    76198
# 인천광역시       43664    63028    70593    69580    86548   108831   107658
# 광주광역시       21506    32852    38227    39769    49779    53357    45743
# 대전광역시       21241    31032    35302    37083    48557    57944    51617
# 울산광역시       16646    26693    29418    28366    33283    39507    37536
# 세종특별자치시      9524    13733    14079    10808     9307    10329    13538
# 경기도        216863   313113   345546   335021   411620   501356   491074
# 강원도         20663    28244    33186    35219    46654    48339    43021
# 충청북도        22631    32948    37693    37809    47397    57064    51561
# ...

# %%
sum= 0
for i in range(len(df)):
    
    for j in range(3,13):
        sum += df.iloc[i,j]
        
df.iloc[i,-2] = sum
df
# Out:
#              0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         726460  1072653  1211077  1211949  1524378  1823908  1737714
# 서울특별시      116614   161429   185689   197425   271237   390716   379852
# 부산광역시       41333    63912    68919    67836    93245   109745   103536
# 대구광역시       31269    49000    55029    57661    74228    81001    76198
# 인천광역시       43664    63028    70593    69580    86548   108831   107658
# 광주광역시       21506    32852    38227    39769    49779    53357    45743
# 대전광역시       21241    31032    35302    37083    48557    57944    51617
# 울산광역시       16646    26693    29418    28366    33283    39507    37536
# 세종특별자치시      9524    13733    14079    10808     9307    10329    13538
# 경기도        216863   313113   345546   335021   411620   501356   491074
# 강원도         20663    28244    33186    35219    46654    48339    43021
# 충청북도        22631    32948    37693    37809    47397    57064    51561
# ...
