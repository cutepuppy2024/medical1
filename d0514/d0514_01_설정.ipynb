# %%
import matplotlib.pyplot as plt
# 마이너스 표시 해결

# 한글설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # : windows 사용자용
# matplotlib.rcParams['font.family'] = 'AppleGothic Gothic'  : Mac 사용자용
matplotlib.rcParams['font.size'] = '15'               # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False 

x = [1,2,3]
y = [2,4,8]
y2 = [1,4,9]
y3 = [7,5,2]

# 그래프 그리기
plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,y3)

# %%
x = [1,2,3]

# 그래프 그리기
plt.plot(x,y)
# 상단 타이틀 - 제목 넣기 : 한글은 설정이 필요
plt.title('막대그래프')
plt.show()  # Text(0.5, 1.0, '막대그래프') : 실행문구 부분이 없어짐, 데이터의 전달도 사라짐. => 실행문구는 확인하는 것이 좋음
# Out:
# Text(0.5, 1.0, '막대그래프')

# %%
# 마이너스 표시 해결
matplotlib.rcParams['axes.unicode_minus'] = False 

x = [-3,-2,-1,0,1,2,3]
y = [2,4,8,10,5,2,9]

plt.plot(x,y)
