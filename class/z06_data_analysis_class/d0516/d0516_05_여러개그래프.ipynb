# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

matplotlib.rcParams['axes.unicode_minus'] = False 
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # : windows 사용자용
matplotlib.rcParams['font.size'] = '10'

# %%
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기  학년
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python   3
# 2번    강태원  구로고  184   40   35   50  55  25        Java   3
# 3번    강호림  구로고  168   80   75   70  80  75  javascript   2
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN   1
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN   1
# 6번    박동현  단지고  202   80  100   95  85  80           C   3
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON   2
# 8번    승근열  단지고  190  100   85   90  95  95          c#   2

# %%
plt.bar(df['이름'],df['국어'])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.plot(df['이름'],df['국어'])
plt.bar(df['이름'],df['영어'])
plt.title('그래프')
# Out:
# Text(0.5, 1.0, '그래프')

# %%
fig,axs= plt.subplots(2,2, figsize=(10,10))

# [0,0] 1번째 그래프 작성
# 범례  :  label
axs[0,0].bar(df['이름'],df['국어'], label='국어점수')
# 범례출력 : legend
axs[0,0].legend()
# 상단 타이틀 : set_title
axs[0,0].set_title('국어 그래프')
# x,y축 글자 표시
axs[0,0].set(xlabel='이름', ylabel='국어점수')
# 그래프내 색상 : set_facecolor
axs[0,0].set_facecolor('#efefef') # 배경색
# 격자표시 : grid
axs[0,0].grid(ls='--',alpha=0.5)

# [0,1] 2번째 그래프  : 꺾은선 그래프 2개
axs[0,1].plot(df['이름'],df['영어'],label='영어점수')
axs[0,1].plot(df['이름'],df['수학'],label='수학점수')
axs[0,1].set_title('영어,수학 그래프')
axs[0,1].legend(loc='upper center')


# [1,0] 3번째 그래프  : 가로 막대 그래프
axs[1,0].barh(df['이름'],df['사회'])


# [1,1] 4번째 그래프  : 꺾은 선 그래프
axs[1,1].plot(df['이름'],df['과학'],color='green',alpha=0.5)
