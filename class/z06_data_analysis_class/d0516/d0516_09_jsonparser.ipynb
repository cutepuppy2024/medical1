# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import requests
import oracledb

matplotlib.rcParams['axes.unicode_minus'] = False 
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # : windows 사용자용
matplotlib.rcParams['font.size'] = '10'

# %%
# https : 보안키가 적용되어 데이터가 넘어옴
url = "http://apis.data.go.kr/B551011/PhotoGalleryService1/galleryList1?serviceKey=W9pkpJL4PH5n%2B0CFILqfVpnIOUvDB1hoKMqpTvqBn2md6uUGEWP0nI3zoa6uOJnnQ4tDrntFwqBNAz0JRdZ7RQ%3D%3D&numOfRows=10&pageNo=1&MobileOS=ETC&MobileApp=AppTest&arrange=A&_type=json"
res = requests.get(url)
res.text
# type(res.text)
# Out:
# '{"response": {"header":{"resultCode":"0000","resultMsg":"OK"},"body": {"items": {"item":[{"galContentId":"3108474","galContentTypeId":"17","galTitle":"치악산국립공원","galWebImageUrl":"http://tong.visitkorea.or.kr/cms2/website/74/3108474.jpg","galCreatedtime":"20240308154547","galModifiedtime":"20240421205153","galPhotographyMonth":"202402","galPhotographyLocation":"강원특별자치도 원주시 소초면","galPhotographer":"한국관광공사 이범수","galSearchKeyword":"치악산국립공원, 강원특별자치도 원주시, 눈, 설경, 겨울, 드론촬영, 드론사진, 항공촬영, 파노라마"},{"galContentId":"3108458","galContentTypeId":"17","galTitle":"거돈사지","galWebImageUrl":"http://tong.visitkorea.or.kr/cms2/website/58/3108458.JPG","galCreatedtime":"20240308152254","galModifiedtime":"20240315102301","galPhotographyMonth":"202402","galPhotographyLocation":"강원특별자치도 원주시 부론면","galPhotographer":"한국관광공사 이범수","galSearchKeyword":"거돈사지, 강원특별자치도 원주시, 사적 제168호, 절터, 사찰터, 눈, 설경, 겨울, 드론촬영, 드론사진, 항공촬영"},{"galContentId":"3108341","galContentTypeId":"17","galTitle":"원주 반계리 은행나무","galWebImageUrl":"http://ton
# ...

# %%
# JSON 데이터로 변경
json_data = res.json()
json_data
# Out:
# {'response': {'header': {'resultCode': '0000', 'resultMsg': 'OK'},
#   'body': {'items': {'item': [{'galContentId': '3108474',
#       'galContentTypeId': '17',
#       'galTitle': '치악산국립공원',
#       'galWebImageUrl': 'http://tong.visitkorea.or.kr/cms2/website/74/3108474.jpg',
#       'galCreatedtime': '20240308154547',
#       'galModifiedtime': '20240421205153',
#       'galPhotographyMonth': '202402',
#       'galPhotographyLocation': '강원특별자치도 원주시 소초면',
#       'galPhotographer': '한국관광공사 이범수',
#       'galSearchKeyword': '치악산국립공원, 강원특별자치도 원주시, 눈, 설경, 겨울, 드론촬영, 드론사진, 항공촬영, 파노라마'},
#      {'galContentId': '3108458',
#       'galContentTypeId': '17',
#       'galTitle': '거돈사지',
#       'galWebImageUrl': 'http://tong.visitkorea.or.kr/cms2/website/58/3108458.JPG',
#       'galCreatedtime': '20240308152254',
#       'galModifiedtime': '20240315102301',
#       'galPhotographyMonth': '202402',
#       'galPhotographyLocation': '강원특별자치도 원주시 부론면',
#       'galPhotographer': '한국관광공사 이범수',
# ...

# %%
datas = json_data['response']['body']['items']['item']
# datas
type(datas)
# Out:
# list

# %%
df = pd.DataFrame(datas)
df
# Out:
#   galContentId galContentTypeId     galTitle  \
# 0      3108474               17      치악산국립공원
# 1      3108458               17         거돈사지
# 2      3108341               17  원주 반계리 은행나무
# 3      3108318               17       한국관광공사
# 4      3107008               17           치킨
# 5      3106911               17          제호탕
# 6      3106888               17           잡채
# 7      3106857               17          육개장
# 8      3106847               17        오이소박이
# 9      3106841               17          오곡밥
#
#                                       galWebImageUrl  galCreatedtime  \
# 0  http://tong.visitkorea.or.kr/cms2/website/74/3...  20240308154547
# 1  http://tong.visitkorea.or.kr/cms2/website/58/3...  20240308152254
# 2  http://tong.visitkorea.or.kr/cms2/website/41/3...  20240308113532
# 3  http://tong.visitkorea.or.kr/cms2/website/18/3...  20240308104529
# 4  http://tong.visitkorea.or.kr/cms2/website/08/3...  20240228141519
# ...

# %%
df['galTitle']
# Out:
# 0        치악산국립공원
# 1           거돈사지
# 2    원주 반계리 은행나무
# 3         한국관광공사
# 4             치킨
# 5            제호탕
# 6             잡채
# 7            육개장
# 8          오이소박이
# 9            오곡밥
# Name: galTitle, dtype: object
