# %%
import pandas as pd
df = pd.read_csv('score.csv',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 6번    박동현  단지고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          c#

# %%
df['키']
df['이름']

df[['키','이름']]
# Out:
#         키   이름
# 지원번호
# 1번    197  강나래
# 2번    184  강태원
# 3번    168  강호림
# 4번    187  김수찬
# 5번    188  김재욱
# 6번    202  박동현
# 7번    188  박혜정
# 8번    190  승근열

# %%
df['키'].max()
# Out:
# 202

# %%
df['키'].mean()
# Out:
# 188.0

# %%
# 복수개를 for문을 돌리지 않고도 비교가능

df['키'] > df['키'].mean()
# Out:
# 지원번호
# 1번     True
# 2번    False
# 3번    False
# 4번    False
# 5번    False
# 6번     True
# 7번    False
# 8번     True
# Name: 키, dtype: bool

# %%
df['키'].min()
# Out:
# 168

# %%
# 선택한 컬럼에서 가장 큰값/작은값 5개 출력(개수지정)
df['키'].nlargest(3)
df['키'].nsmallest(4)
# Out:
# 지원번호
# 3번    168
# 2번    184
# 4번    187
# 5번    188
# Name: 키, dtype: int64

# %%
# 오라클의 그룹함수와 비교 -> 

df['키'].max()
df['키'].min()
df['키'].mean()
df['키'].count()
df['키'].describe()
df['키'].info()

df['SW특기'].count()  # 주의 ! -> NaN 데이터는 개수에 들어가지 않음
df['국어'].sum()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 8 entries, 1번 to 8번
# Series name: 키
# Non-Null Count  Dtype
# --------------  -----
# 8 non-null      int64
# dtypes: int64(1)
# memory usage: 428.0+ bytes
# 500

# %%
df['학교'].unique()   # 중복을 제거하여 배열을 알려줌 -> array(['구로고', '단지고']
df['학교'].nunique()  # 중복제거후 개수출력
# Out:
# array(['구로고', '단지고'], dtype=object)

# %%
import pandas as pd
df = pd.read_csv('students.csv',encoding='utf-8',index_col='no')
df
# Out:
#             id    pw      name         phone                      email  \
# no
# 1      Joelynn  6856   Paschke  726-935-7279         jpaschke0@time.com
# 2       Bambie  8439   Henriet  106-961-2837        bhenriet1@github.io
# 3         Orin  4720   Torresi  283-535-0981      otorresi2@vinaora.com
# 4         Puff  8047   Gilvary  677-319-4536        pgilvary3@bbc.co.uk
# 5      Godfree  5878  Gauchier  451-834-0498        ggauchier4@uiuc.edu
# ...        ...   ...       ...           ...                        ...
# 996    Wilburt  4365      Eyrl  551-729-0172  weyrlrn@ezinearticles.com
# 997    Broddie  1444  Chalfant  961-627-7363  bchalfantro@reference.com
# 998     Baxter  3156   Peacham  349-596-4800       bpeachamrp@vimeo.com
# 999    Ignacio  2412    Vaneev  130-508-8945            ivaneevrq@is.gd
# 1000  Wallache  2512     Bleas  702-366-1309         wbleasrr@youku.com
#
#                     address gender     major  grade hobby       ip_address
# no
# ...

# %%
df['grade'].unique()  
df['hobby'].unique()
# Out:
# array(['run', 'game', 'golf', 'swim', 'book'], dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'pw', 'name', 'phone', 'email', 'address', 'gender', 'major',
#        'grade', 'hobby', 'ip_address'],
#       dtype='object')

# %%
df[['id','name','hobby']]
df.columns              # column 전체 보기
df.columns[0:5]         # 0~4번까지 보기
df.columns[[0,1,5]]     # 0,1,5 컬럼보기

df[['id','name','address']]
df[df.columns[[0,1,5]]] # 선택한 컬럼을 테이블 형태로 보기
df[df.columns[-1]]     
# df[df.columns[-2].unique()]  # error
df[df.columns[-2]].unique()  # df.columns 배열을 적용하여 컬럼출력
# df['hobby'].unique()
# Out:
# array(['run', 'game', 'golf', 'swim', 'book'], dtype=object)

# %%
import pandas as pd
df = pd.read_csv('score.csv',index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고  197   90   85  100  95  85      Python
# 2번    강태원  구로고  184   40   35   50  55  25        Java
# 3번    강호림  구로고  168   80   75   70  80  75  javascript
# 4번    김수찬  구로고  187   40   60   70  75  80         NaN
# 5번    김재욱  구로고  188   15   20   10  35  10         NaN
# 6번    박동현  단지고  202   80  100   95  85  80           C
# 7번    박혜정  단지고  188   55   65   45  40  35      PYTHON
# 8번    승근열  단지고  190  100   85   90  95  95          c#

# %%
# 컬럼의 모든 데이터를 가져오기
df['키']
df[['키','이름']]

# 컬럼만 가져오기
df.columns
df.columns[0:3]
df.columns[[1,4,6]]

# df[컬럼명]
df[df.columns[[1,4,6]]]
# Out:
# Index(['학교', '영어', '과학'], dtype='object')

# %%
df['키']
df['키'][0:3]
df['키'][-1]
df['키'][0]

df[['키','이름']][1:4]
df[df.columns[[1,3,4]]][1:4]
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_24800\149562882.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['키'][-1]
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_24800\149562882.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['키'][0]
#        학교  국어  영어
# 지원번호
# 2번    구로고  40  35
# 3번    구로고  80  75
# 4번    구로고  40  60

# %%
# index지정, 컬럼부분 명령어
# 파일저장, 파일읽기

# %%
# rows 데이터 가져오기

df[0:3]  # DataFrame에서 슬라이싱,  loc는 컬럼과 값을 세로로 출력
df[2:]
# df[[0,1,3]] #error
df.iloc[[0,1,3]]  # rows데이터 부분적으로 가져오기

df.head()
df.tail()
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# 4번    김수찬  구로고  187   40   60  70  75  80     NaN
# 5번    김재욱  구로고  188   15   20  10  35  10     NaN
# 6번    박동현  단지고  202   80  100  95  85  80       C
# 7번    박혜정  단지고  188   55   65  45  40  35  PYTHON
# 8번    승근열  단지고  190  100   85  90  95  95      c#

# %%
df[['이름','키','학교']][0:3]
# Out:
#        이름    키   학교
# 지원번호
# 1번    강나래  197  구로고
# 2번    강태원  184  구로고
# 3번    강호림  168  구로고
