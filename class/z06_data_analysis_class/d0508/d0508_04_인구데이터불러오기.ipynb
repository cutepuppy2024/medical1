# %%
import pandas as pd

# 1. 연령별 인구현황 검색 excel파일 저장

df = pd.read_excel('20240103_인구.xlsx')
df.to_excel('20240103_인구1.xlsx')
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
#  2. 상단 3개를 삭제후 가져오기
df = pd.read_excel('20240103_인구.xlsx',skiprows=3)
df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#         행정기관코드       행정기관       남 인구수     연령구간인구수     0~4세       5~9세  \
# 0            0       전국    25,631,538  25,631,538  726,460  1,072,653
# 1   1100000000    서울특별시     4,567,739   4,567,739  116,614    161,429
# 2   2600000000    부산광역시     1,618,749   1,618,749   41,333     63,912
# 3   2700000000    대구광역시     1,162,217   1,162,217   31,269     49,000
# 4   2800000000    인천광역시     1,486,300   1,486,300   43,664     63,028
# 5   2900000000    광주광역시       706,724     706,724   21,506     32,852
# 6   3000000000    대전광역시       721,037     721,037   21,241     31,032
# 7   3100000000    울산광역시       570,113     570,113   16,646     26,693
# 8   3600000000  세종특별자치시       191,769     191,769    9,524     13,733
# ...

# %%
#  3. 행정기관 index 지정
df = pd.read_excel('20240103_인구.xlsx',skiprows=3,index_col='행정기관')
#  4. 상단 5개만 출력하시오.
df.head()
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#              행정기관코드       남 인구수     연령구간인구수     0~4세       5~9세     10~14세  \
# 행정기관
# 전국                0  25,631,538  25,631,538  726,460  1,072,653  1,211,077
# 서울특별시    1100000000   4,567,739   4,567,739  116,614    161,429    185,689
# 부산광역시    2600000000   1,618,749   1,618,749   41,333     63,912     68,919
# 대구광역시    2700000000   1,162,217   1,162,217   31,269     49,000     55,029
# 인천광역시    2800000000   1,486,300   1,486,300   43,664     63,028     70,593
#
#             15~19세     20~24세     25~29세     30~34세  ...   55~59세.5  \
# 행정기관                                                 ...
# 전국       1,211,949  1,524,378  1,823,908  1,737,714  ...  2,026,849
# 서울특별시      197,425    271,237    390,716    379,852  ...    352,974
# ...

# %%
#  3. 행정기관 index 지정
df = pd.read_excel('20240103_인구.xlsx',skiprows=3,index_col='행정기관',usecols='B,E:Y')
#  4. 상단 5개만 출력하시오.
df.head()
df.columns
df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         726,460  1,072,653  1,211,077  1,211,949  1,524,378  1,823,908
# 서울특별시      116,614    161,429    185,689    197,425    271,237    390,716
# 부산광역시       41,333     63,912     68,919     67,836     93,245    109,745
# 대구광역시       31,269     49,000     55,029     57,661     74,228     81,001
# 인천광역시       43,664     63,028     70,593     69,580     86,548    108,831
# 광주광역시       21,506     32,852     38,227     39,769     49,779     53,357
# 대전광역시       21,241     31,032     35,302     37,083     48,557     57,944
# 울산광역시       16,646     26,693     29,418     28,366     33,283     39,507
# 세종특별자치시      9,524     13,733     14,079     10,808      9,307     10,329
# ...

# %%
# 여성의 정보만 출력
w_df = pd.read_excel('20240103_인구.xlsx',skiprows=3,index_col='행정기관',usecols='B,AB:AV')
w_df.head()

# 남성과 여성의 컬럼 맞추기
w_df.columns = df.columns
w_df.columns
w_df
# Out:
# c:\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         691,045  1,020,598  1,144,645  1,134,811  1,402,493  1,642,682
# 서울특별시      109,390    154,162    176,096    189,009    304,285    418,972
# 부산광역시       39,356     60,582     65,329     64,001     88,307    102,363
# 대구광역시       29,517     47,039     51,645     53,188     65,933     71,873
# 인천광역시       41,505     59,985     66,881     65,904     80,089     99,535
# 광주광역시       20,633     31,124     35,819     36,800     46,059     48,645
# 대전광역시       20,120     29,266     33,099     34,644     45,960     50,861
# 울산광역시       16,024     25,063     27,185     25,355     25,988     29,820
# 세종특별자치시      9,323     13,207     13,629     10,886      8,405     10,259
# ...

# %%
# rows
# df[0:3]  
# # df[1]    # 리스트 안에 1개만 들어가는 것은 안됨  
# df.iloc[0] 
# df.head(3)
# df.tail(2)
# df[df.columns[-1]]


# df.iloc[0]                       # 0번째 rows 데이터 가져오기
# df.iloc[0].str                   # 타입변경
# df.iloc[0].str.replace(",","")   # replace 함수적용
df.iloc[0] = df.iloc[0].str.replace(",","").astype(int)

# %%
df.describe()
# Out:
#           0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세   35~39세  \
# count       18       18       18       18       18       18       18       18
# unique      18       18       18       18       18       18       18       18
# top     726460  1072653  1211077  1211949  1524378  1823908  1737714  1684266
# freq         1        1        1        1        1        1        1        1
#
#          40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  75~79세  \
# count        18       18  ...       18       18       18       18      18
# unique       18       18  ...       18       18       18       18      18
# top     2055130  2039606  ...  2052227  2097254  1554976  1038388  713448
# freq          1        1  ...        1        1        1        1       1
#
#         80~84세  85~89세  90~94세  95~99세  100세 이상
# count       18      18      18      18       18
# unique      18      18      18      18       18
# top     507915  212726   54180    8880     1307
# ...
