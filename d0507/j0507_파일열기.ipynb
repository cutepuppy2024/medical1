# %%
import pandas as pd

# 파일 읽어오기  : csv, txt, excel 파일

# csv 파일 읽어오기
df = pd.read_csv('movie.csv')

# txt 파일 읽어오기
df = pd.read_csv('movie_t.txt')

# excel 파일 읽어오기
df = pd.read_excel('movie_e.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 12
#       9 df = pd.read_csv('movie_t.txt')
#      11 # excel 파일 읽어오기
# ---> 12 df = pd.read_excel('movie_e.xlsx')
#      13 df
#
# File c:\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Python312\Lib\site-packages\pandas\io\excel\_base.py:1554, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
# -> 1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#    1559 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1560 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
df = pd.read_csv('movie.csv',encoding='utf-8')
df
# Out:
#    year    title  viewer  rating
# 0  2019     극한직업    1626     3.6
# 1  2020  남산의 부장들     475     3.5
# 2  2021     모가디슈     361     3.6
# 3  2022    범죄도시2    1269     3.5
# 4  2023    서울의 봄    1312     4.1

# %% [markdown]
# ### skiprows : 상단부분 지정한 크기만큼 제거 후 읽어오기

# %%
df = pd.read_csv('stu.csv',skiprows=1)
df
# Out:
#    1번  강나래  구로고  197   90   85  100  95  85.1      Python
# 0  2번  강태원  구로고  184   40   35   50  55    25        Java
# 1  3번  강호림  구로고  168   80   75   70  80    75  javascript
# 2  4번  김수찬  구로고  187   40   60   70  75    80         NaN
# 3  5번  김재욱  구로고  188   15   20   10  35    10         NaN
# 4  6번  박동현  단지고  202   80  100   95  85    80           C
# 5  7번  박혜정  단지고  188   55   65   45  40    35      PYTHON
# 6  8번  승근열  단지고  190  100   85   90  95    95          c#

# %% [markdown]
# ### nrows  :  지정한 개수만큼 가져오기

# %%
df =pd.read_csv('stu.csv',nrows=4)
df
# Out:
#   지원번호   이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 0   1번  강나래  구로고  197  90  85  100  95  85      Python
# 1   2번  강태원  구로고  184  40  35   50  55  25        Java
# 2   3번  강호림  구로고  168  80  75   70  80  75  javascript
# 3   4번  김수찬  구로고  187  40  60   70  75  80         NaN

# %%
df = pd.read_csv('stu.csv',nrows=4, skiprows=1)
# df.set_index('')
# df

df.set_index('1번',inplace=True)
df

# 파일저장
# df.to_csv('stu2.csv',encoding='utf-8-sig')
# Out:
#     강나래  구로고  197  90  85  100  95  85.1      Python
# 1번
# 2번  강태원  구로고  184  40  35   50  55    25        Java
# 3번  강호림  구로고  168  80  75   70  80    75  javascript
# 4번  김수찬  구로고  187  40  60   70  75    80         NaN
# 5번  김재욱  구로고  188  15  20   10  35    10         NaN

# %%
df = pd.read_csv('stu.csv')
df.set_index('지원번호',inplace=True)
df
# df.index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 6
#       3 df
#       4 # df.index
# ----> 6 df.set_index('1번',inplace=True)
#       7 df
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:6122, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6119                 missing.append(col)
#    6121 if missing:
# -> 6122     raise KeyError(f"None of {missing} are in the columns")
#    6124 if inplace:
#    6125     frame = self
#
# KeyError: "None of ['1번'] are in the columns"
